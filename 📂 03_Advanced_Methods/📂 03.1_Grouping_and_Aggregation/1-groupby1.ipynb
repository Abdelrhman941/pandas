# %%
import numpy as np                  # type: ignore
import pandas as pd                 # type: ignore
import matplotlib.pyplot as plt     # type: ignore

# %% [markdown]
# <div style="background-color:rgb(60, 255, 0) ; color:rgb(44, 42, 42); width: 100%; height: 50px; text-align: center; font-weight: bold; line-height: 50px; margin: 10px 0; font-size: 24px;">
# Example 1️⃣
# </div>

# %%
data=pd.read_csv("../../datasets/drinks.csv")
data.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# ...

# %%
data[data.country=="Egypt"]
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 53   Egypt              6                4              1
#
#     total_litres_of_pure_alcohol continent
# 53                           0.2    Africa

# %% [markdown]
#  ---
# ## 📊 **Difference Between `mean()` & `groupby().mean()`**
#
# ### 🔎 **1️⃣ Overall Mean – `mean()`**
# ✔️ Computes the **average** of a specific column across **all data**
#
# ```python
# print(data.beer_servings.mean())  # Average beer_servings for all countries
# ```
#
# ### 🌍 **2️⃣ Grouped Mean – `groupby().mean()`**
# ✔️ **Calculates the mean for each group separately**
# ✔️ Useful when analyzing data by categories (e.g., continents)
#
# ```python
# print(data.groupby("continent").beer_servings.mean())  # Average beer_servings per continent
# ```
#
# ### ⚠️ **Handling Errors – `numeric_only=True`**
# ✔️ groupby().mean() _sometimes fails if non-numeric columns exist_
# ✔️ Use numeric_only=True to avoid errors
#
# ```python
# data.groupby("continent").mean(numeric_only=True)
# ```
#
# > ## 🚀 Summary:
#
# `mean()` → **Calculates a single overall average**
# `groupby().mean()` → **Computes averages per category/group**

# %%
data.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
print(data.beer_servings.mean())                            # Average beer_servings for all countries
print("-----------------")
print(data.groupby("continent").beer_servings.mean())       # Average beer_servings per continent
print("-----------------")
# data.groupby("continent").mean()  # sometime it error
data.groupby("continent").mean(numeric_only=True)
# Out:
# 106.16062176165804
# -----------------
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64
# -----------------
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# ...

# %%
data.groupby("continent").mean(numeric_only=True).plot(kind="bar")
plt.show()

# %% [markdown]
# ---------
# > ### defined specific continent & sort it

# %%
# Filter data by Africa 
print(data[data.continent=="Africa"].beer_servings.mean())
print("------")
data[data.continent=="Africa"].sort_values(by="beer_servings" ,ascending=False)
# Out:
# 61.471698113207545
# ------
#                       country  beer_servings  spirit_servings  wine_servings  \
# 117                   Namibia            376                3              1
# 62                      Gabon            347               98             59
# 159              South Africa            225               76             81
# 4                      Angola            217               57             45
# 22                   Botswana            173               35             35
# 152                Seychelles            157               25             51
# 31                   Cameroon            147                1              4
# 29                 Cabo Verde            144               56             16
# 108                 Mauritius             98               31             18
# 55          Equatorial Guinea             92                0            233
# 164                 Swaziland             90                2              2
# ...

# %% [markdown]
# ---
# > ### max column & find its values

# %%
# What is the maximum beer_servings for each continent?
result=data.groupby("continent").beer_servings.max()
print(result)

# Return rows with the maximum beer_servings in each continent
data[np.isin(data.beer_servings, result.values)]
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64
#                 country  beer_servings  spirit_servings  wine_servings  \
# 45       Czech Republic            361              170            134
# 117             Namibia            376                3              1
# 129               Palau            306               63             23
# 130              Panama            285              104             18
# 141  Russian Federation            247              326             73
# 188           Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 45                           11.8         Europe
# 117                           6.8         Africa
# 129                           6.9        Oceania
# 130                           7.2  North America
# ...

# %% [markdown]
# > ### **⚠️ you can see more data cleaning explain in  [2-groupby2](2-groupby2.ipynb)**
